# %% [markdown]
# <a href="https://colab.research.google.com/github/ND3MW4/Introducton_to_Shell_Scripting_workshop/blob/main/Web%20Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title   :  Webscraping
# # Name    :  Denis Ndemwa
# # Date    :  2025 May 13th

# %% [markdown]
# 📦 Importing libraries that I will need for webscraping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# 🛠️ Set URL of website in a variable

# %%
url = 'https://www.scrapethissite.com/pages/forms/?page_num=16'
page = requests.get(url)
page
# Out:
# <Response [200]>

# %% [markdown]
# 🍲 Use BeautifulSoup to extract the HTML content

# %%
soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# 📋 Extract the table with the Hockey Scores

# %%
hockey_table = soup.find_all('table', class_='table')
print(hockey_table)
# Out:
# [<table class="table">
# <tr>
# <th>
#                             Team Name
#                         </th>
# <th>
#                             Year
#                         </th>
# <th>
#                             Wins
#                         </th>
# <th>
#                             Losses
#                         </th>
# <th>
#                             OT Losses
#                         </th>
# <th>
#                             Win %
#                         </th>
# <th>
#                             Goals For (GF)
#                         </th>
# <th>
#                             Goals Against (GA)
#                         </th>
# <th>
#                             + / -
#                         </th>
# </tr>
# <tr class="team">
# <td class="name">
#                             Buffalo Sabres
#                         </td>
# <td class="year">
#                             2005
#                         </td>
# <td class="wins">
# ...

# %% [markdown]
# 📝 Extract the column headings

# %%
table_titles = soup.find_all('th')
hockey_table_title = [title.text.strip() for title in table_titles]
print(hockey_table_title)
# Out:
# ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']

# %% [markdown]
# 🔍 Find the first table (adjust if needed)

# %%
table = soup.find('table')

# %% [markdown]
# 📄 Get all rows in the table

# %%
rows = table.find_all('tr')

# %% [markdown]
# 🔁 Loop through and print the first 25 data rows (excluding header)

# %%
for i, row in enumerate(rows[0:26], start=1):  # skip header (index 0)
    cells = row.find_all(['td', 'th'])
    row_data = [cell.get_text(strip=True) for cell in cells]
    print(f"Row {i}:", row_data)
# Out:
# Row 1: ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']
# Row 2: ['Buffalo Sabres', '2005', '52', '24', '6', '0.634', '281', '239', '42']
# Row 3: ['Calgary Flames', '2005', '46', '25', '11', '0.561', '218', '200', '18']
# Row 4: ['Carolina Hurricanes', '2005', '52', '22', '8', '0.634', '294', '260', '34']
# Row 5: ['Columbus Blue Jackets', '2005', '35', '43', '4', '0.427', '223', '279', '-56']
# Row 6: ['Chicago Blackhawks', '2005', '26', '43', '13', '0.317', '211', '285', '-74']
# Row 7: ['Colorado Avalanche', '2005', '43', '30', '9', '0.524', '283', '257', '26']
# Row 8: ['Dallas Stars', '2005', '53', '23', '6', '0.646', '265', '218', '47']
# Row 9: ['Detroit Red Wings', '2005', '58', '16', '8', '0.707', '305', '209', '96']
# Row 10: ['Edmonton Oilers', '2005', '41', '28', '13', '0.5', '256', '251', '5']
# Row 11: ['Florida Panthers', '2005', '37', '34', '11', '0.451', '240', '257', '-17']
# ...

# %% [markdown]
# 💾Save the column headings onto a Pandas DataFrame

# %%
df = pd.DataFrame(columns=hockey_table_title)
df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %% [markdown]
# 🔍📊 Inspect the resulting DataFrame

# %%
df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %% [markdown]
# 📥 Save to a .csv file in the current folder

# %%
df.to_csv(r'./Hockey.csv')
